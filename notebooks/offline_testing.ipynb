# %%
from joblib import load
import os
import pandas as pd

# %%
os.chdir(r'C:\SML_Projects\SML_airplane_price_project')

# %%
model = load('pipeline/full_pipeline.joblib')

# %% [markdown]
# # User data

# %%
airplane = pd.DataFrame({
    'Model': ['Airbus A320'],
    'Year_of_Manufacture': [1995],
    'Number_of_Engines': [2],
    'Engine_Type': ['Turbofan'],
    'Capacity': [150],
    'Fuel_Consumption_(L/hour)': [26.4],
    'Hourly_Maintenance_Cost_($)': [5850.12],
    'Age': [30],
    'Sales_Region': ['Europe'],
    'Price_($)': [41200000]
})

# %%
pred = model.predict(airplane)[0]
print(f"Predicted range: {pred:.0f}")
# Out:
# Predicted range: 5494
